# %%
# !pip install -r requirements-dev.txt
# Out:
# ...
#   Obtaining dependency information for requests from https://files.pythonhosted.org/packages/1e/db/4254e3eabe8020b458f1a747140d32277ec7a271daf1d235b70dc0b4e6e3/requests-2.32.5-py3-none-any.whl.metadata
#   Using cached requests-2.32.5-py3-none-any.whl.metadata (4.9 kB)
# ...
#   Obtaining dependency information for charset_normalizer<4,>=2 from https://files.pythonhosted.org/packages/ed/27/c6491ff4954e58a10f69ad90aca8a1b6fe9c5d3c6f380907af3c37435b59/charset_normalizer-3.4.4-cp311-cp311-macosx_10_9_universal2.whl.metadata
#   Using cached charset_normalizer-3.4.4-cp311-cp311-macosx_10_9_universal2.whl.metadata (37 kB)
# ...
#   Obtaining dependency information for idna<4,>=2.5 from https://files.pythonhosted.org/packages/0e/61/66938bbb5fc52dbdf84594873d5b51fb1f7c7794e9c0f5bd885f30bc507b/idna-3.11-py3-none-any.whl.metadata
#   Using cached idna-3.11-py3-none-any.whl.metadata (8.4 kB)
# ...

# %%
import requests

response = requests.get('https://api.sampleapis.com/coffee/hot')

# %%
data = response.json()
data
# Out:
# [{'title': 'Apelsinjuice',
#   'description': 'Vi har inget att säga om vår nypressade apelsinjuice. Du måste prova den själv.',
#   'ingredients': ['Färska Apelsiner', 'Is'],
#   'image': 'https://images.unsplash.com/photo-1600271886742-f049cd451bba?auto=format&fit=crop&q=60&w=800&ixlib=rb-4.0.3&ixid=M3wxMjA3fDB8MHxzZWFyY2h8NzF8fG9yYW5nZSUyMGp1aWNlfGVufDB8fDB8fHww',
#   'id': 18},
#  {'description': 'Cold brew',
#   'title': 'Cold brew',
#   'image': 'images/cold brew.jpg',
#   'ingredients': ['Coffee', 'Ice'],
#   'id': 20},
#  {'title': 'title',
#   'description': 'desc',
#   'ingredients': '[t,e,s,t]',
#   'image': 'gerald',
#   'id': '313513'},
#  {'title': 'Espresso',
#   'description': 'A tasty tret',
#   'ingredients': ['Espresso'],
#   'image': 'https://cdn.pixabay.com/photo/2016/11/29/13/17/coffee-1869772_1280.jpg',
#   'id': 'Rv6kUA-'},
#  {'title': 'Hot Banglore Coffee',
#   'description': 'Hot coffee is good cold.',
#   'ingredients': ['Coffee Beans'],
# ...

# %%
import pandas as pd

df = pd.DataFrame(data)
df.head()
# Out:
#                  title                                        description  \
# 0         Apelsinjuice  Vi har inget att säga om vår nypressade apelsi...
# 1            Cold brew                                          Cold brew
# 2                title                                               desc
# 3             Espresso                                       A tasty tret
# 4  Hot Banglore Coffee                           Hot coffee is good cold.
#
#               ingredients                                              image  \
# 0  [Färska Apelsiner, Is]  https://images.unsplash.com/photo-160027188674...
# 1           [Coffee, Ice]                               images/cold brew.jpg
# 2               [t,e,s,t]                                             gerald
# 3              [Espresso]  https://cdn.pixabay.com/photo/2016/11/29/13/17...
# 4          [Coffee Beans]  https://images.unsplash.com/photo-157609276824...
#
#         id
# 0       18
# 1       20
# 2   313513
# ...

# %%
response = requests.get('https://uperp.puthisastra.edu.kh/locales/km/translation.json')
data = response.json()
df = pd.DataFrame(data)
df.head()
# Out:
#                                                                nested  \
# occupationInfo      {'occupationId': 'មុខរបរ', 'occupationPlace': ...
# currentAddressInfo  {'homeStreetKh': 'ផ្ទះនិងផ្លូវ (KH)', 'homeStr...
# email               {'up': 'UP អ៊ីម៉ែល', 'personal': 'អ៊ីម៉ែលផ្ទាល...
# emergencyInfo       {'name': 'ឈ្មោះ', 'genderId': 'ភេទ', 'relation...
# familyInfo          {'spouseName': 'ឈ្មោះប្តីប្រពន្ធ', 'spouseOccu...
#
#                    shortcut birthday       tr messages status
# occupationInfo          NaN      NaN      NaN      NaN    NaN
# currentAddressInfo      NaN      NaN      NaN      NaN    NaN
# email                   NaN      NaN  អ៊ីម៉ែល      NaN    NaN
# emergencyInfo           NaN      NaN      NaN      NaN    NaN
# familyInfo              NaN      NaN      NaN      NaN    NaN

# %%
from pandas import json_normalize

df = pd.DataFrame(json_normalize(data))
df.head()
# Out:
#   nested.occupationInfo.occupationId nested.occupationInfo.occupationPlace  \
# 0                             មុខរបរ                     ទីកន្លែងអាជីវកម្ម
#
#   nested.currentAddressInfo.homeStreetKh  \
# 0                      ផ្ទះនិងផ្លូវ (KH)
#
#   nested.currentAddressInfo.homeStreetEng  \
# 0                       ផ្ទះនិងផ្លូវ (EN)
#
#   nested.currentAddressInfo.provinceId nested.currentAddressInfo.districtId  \
# 0                                ខេត្ត                                ស្រុក
#
#   nested.currentAddressInfo.communeId nested.currentAddressInfo.villageId  \
# 0                                 ឃុំ                                ភូមិ
#
#   nested.email.up nested.email.personal  ...                    status.200  \
# 0      UP អ៊ីម៉ែល    អ៊ីម៉ែលផ្ទាល់ខ្លួន  ...  ការទាញយកទិន្នន័យបានជោគជ័យ...
#
#                       status.201                  status.204  \
# 0  ការបញ្ចូលទិន្នន័យបានជោគជ័យ...  ការលុបទិន្នន័យបានជោគជ័យ...
#
# ...
